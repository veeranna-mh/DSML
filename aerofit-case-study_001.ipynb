# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('aerofit_treadmill.csv')

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# ### dataset has 180 records and 9 features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# ### 3 features have categorical data; one feature (Fitness) which is a rating on a scale of 1 to 5 is also a
# ### categorical variable with numerical ratings; rest of the features have integer data types

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# ### No "NA"s / "NaN" in the data set

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include='object')
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
products=df['Product'].value_counts()

# %%
products.index
# Out:
# Index(['KP281', 'KP481', 'KP781'], dtype='object', name='Product')

# %%
products.values
# Out:
# array([80, 60, 40], dtype=int64)

# %%
products
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
sns.barplot(x=products.index,y=products.values)
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ### KP281 is the highest selling product followed by KP481 and KP781

# %%
genders=df['Gender'].value_counts()

# %%
genders
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
genders.index
# Out:
# Index(['Male', 'Female'], dtype='object', name='Gender')

# %%
genders.values
# Out:
# array([104,  76], dtype=int64)

# %%
sns.barplot(x=genders.index,y=genders.values)
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ### 104 Males and 76 Females in the dataset

# %%
education=df['Education'].value_counts()

# %%
education
# Out:
# Education
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: count, dtype: int64

# %% [markdown]
# ### 85 people have 16 years of education; 55 have 14 years of education; 23 have 18 years of education

# %%
sns.barplot(x=education.index,y=education.values)
# Out:
# <Axes: xlabel='Education'>

# %% [markdown]
# ### people with 16 years education are highest (85 people), followed by people with 14 years education (55
# ### people) and people with 18 years education (23 people); people with less than 14 years education and
# ### more than 18 years education are relatively very less.

# %%
sns.boxplot(data=df,x='Product',y='Income')
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %% [markdown]
# ### The above box plot shows that higher income people go for KP781., medium income people go for KP481,
# ### Medium to lower income people go for KP281

# %%
sns.boxplot(data=df,x='Product',y='Age')
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %% [markdown]
# ### Younger people (age ~24 to ~30) have affinity towards KP781.
# ### Age group is more wider for people who prefer KP481 and KP281

# %%
sns.boxplot(data=df,x='Product',y='Education')
# Out:
# <Axes: xlabel='Product', ylabel='Education'>

# %% [markdown]
# ### more educated (16 years and more) people are preferring KP781

# %%
sns.boxplot(data=df,x='Product',y='Fitness')
# Out:
# <Axes: xlabel='Product', ylabel='Fitness'>

# %% [markdown]
# ### more fitness conscious people are freferring KP781

# %%
sns.boxplot(data=df,x='Product',y='Usage')
# Out:
# <Axes: xlabel='Product', ylabel='Usage'>

# %% [markdown]
# ### people who use the product more (4 times a week or more) have preferred KP781

# %%
sns.boxplot(data=df,x='Product',y='Miles')
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %% [markdown]
# ### people who walk (run) more ~150 miles or more have preferred KP781

# %%
sns.boxplot(data=df,x='Gender',y='Income')
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
sns.boxplot(data=df,x='Gender',y='Education')
# Out:
# <Axes: xlabel='Gender', ylabel='Education'>

# %%
sns.boxplot(data=df,x='Gender',y='Fitness')
# Out:
# <Axes: xlabel='Gender', ylabel='Fitness'>

# %% [markdown]
# ### Women are less conscious about fitness compared to men

# %%
sns.boxplot(data=df,x='Gender',y='Age')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Gender',y='Usage')
# Out:
# <Axes: xlabel='Gender', ylabel='Usage'>

# %% [markdown]
# ### women have less usage compared to men

# %%
sns.boxplot(data=df,x='Gender',y='Miles')
# Out:
# <Axes: xlabel='Gender', ylabel='Miles'>

# %% [markdown]
# ### data shows men walk (run) more miles compared to women

# %%
pd.crosstab(df['Product'], df['Gender'])
# Out:
# Gender   Female  Male
# Product
# KP281        40    40
# KP481        29    31
# KP781         7    33

# %%
pd.crosstab(df['Age'], df['Product'])
# Out:
# Product  KP281  KP481  KP781
# Age
# 18           1      0      0
# 19           3      1      0
# 20           2      3      0
# 21           4      3      0
# 22           4      0      3
# 23           8      7      3
# 24           5      3      4
# 25           7     11      7
# 26           7      3      2
# 27           3      1      3
# 28           6      0      3
# 29           3      1      2
# 30           2      2      3
# 31           2      3      1
# 32           2      2      0
# 33           2      5      1
# 34           2      3      1
# 35           3      4      1
# 36           1      0      0
# 37           1      1      0
# 38           4      2      1
# 39           1      0      0
# 40           1      3      1
# 41           1      0      0
# 42           0      0      1
# 43           1      0      0
# 44           1      0      0
# 45           0      1      1
# 46           1      0      0
# 47           1      0      1
# 48           0      1      1
# ...

# %%
pd.crosstab(df['Product'], df['Education'])
# Out:
# Education  12  13  14  15  16  18  20  21
# Product
# KP281       2   3  30   4  39   2   0   0
# KP481       1   2  23   1  31   2   0   0
# KP781       0   0   2   0  15  19   1   3

# %%
pd.crosstab(df['Product'], df['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# KP281                 48      32
# KP481                 36      24
# KP781                 23      17

# %%
pd.crosstab(df['Product'], df['Usage'])
# Out:
# Usage     2   3   4   5  6  7
# Product
# KP281    19  37  22   2  0  0
# KP481    14  31  12   3  0  0
# KP781     0   1  18  12  7  2

# %%
pd.crosstab(df['Product'], df['Fitness'])
# Out:
# Fitness  1   2   3  4   5
# Product
# KP281    1  14  54  9   2
# KP481    1  12  39  8   0
# KP781    0   0   4  7  29

# %% [markdown]
# ### I felt excel is more suitable for summarising contingency tables; so used excel for the same.

# %% [markdown]
# ## From excel: marginal probabilities (Gender based)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## From Excel: Row relative and Column relative frequencies (probabilities)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### From Excel: marginal probabilities ( Education based)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## From Excel: Row relative and Column relative frequencies (probabilities)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## From Excel: marginal probabilities (Marital status based)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## From Excel: Row relative and Column Relative frequencies (probabilities)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## From Excel: marginal probabilities based on Fitness ratings
# ![image.png](attachment:image.png)

# %% [markdown]
# ## From Excel: Row relative and Column relative frequencies (probabilities)
#
# ![image.png](attachment:image.png)

# %%
sns.scatterplot(data=df, x='Fitness',y='Miles',hue="Gender")
# Out:
# <Axes: xlabel='Fitness', ylabel='Miles'>

# %%
sns.scatterplot(data=df, x='Education',y='Miles', hue='Gender')
# Out:
# <Axes: xlabel='Education', ylabel='Miles'>

# %%
sns.scatterplot(data=df, x='Product',y='Miles',hue='Gender')
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %% [markdown]
# ### women have bought KP281 preferrably where as men have preferred better versions of the products

# %%
sns.scatterplot(data=df, x='Age',y='Miles',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Miles'>

# %% [markdown]
# ### Younger people have more miles covered compared to older people; predominantly women have lesser
# ### miles covered.

# %%
sns.scatterplot(data=df, x='Income',y='Miles',hue='Gender')
# Out:
# <Axes: xlabel='Income', ylabel='Miles'>

# %% [markdown]
# ### interesting to see a dense cluster of lower income and lower miles people and
# ### a rarely distributed higher income and higher miles people cluster

# %%
sns.scatterplot(data=df, x='MaritalStatus',y='Miles',hue='Gender')
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Miles'>

# %% [markdown]
# ### Partnered people have more miles covered compared to singles... (little counter intuitive at least for me)

# %% [markdown]
# ### overall:  people who have 14 to 18 years of education are more inclined towards fitness and prefer
# ### products with more features.
